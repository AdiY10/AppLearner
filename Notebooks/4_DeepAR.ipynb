# %%
import sys
# caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(2, 'C:\\Users\\itay3\\VirtualCodeProjects\\AppLearner-1\\src')
import framework__deepar as deepAR
import framework__test_bench_deepar as bench

# %%
test_to_perform = (
    # Container CPU
    {"metric": "container_cpu", "app": "kube-rbac-proxy", "prediction length": 16, "sub sample rate": 10, "data length limit": 30, "fixed length of samples": 100, "plot": True},
    {"metric": "container_cpu", "app": "dns",             "prediction length": 16, "sub sample rate": 10, "data length limit": 30, "fixed length of samples": 100, "plot": True}
    # {"metric": "container_cpu", "app": "collector",       "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # # Container Memory
    # {"metric": "container_mem", "app": "nmstate-handler", "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_mem", "app": "coredns",         "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_mem", "app": "keepalived",      "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # # Node Memory
    # {"metric": "node_mem",      "app": "moc/smaug",       "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "node_mem",      "app": "emea/balrog",     "prediction length": 16, "sub sample rate": 30, "data length limit": 30}
)

# %%
tb = bench.TestBenchDeepAR(
    class_to_test=deepAR.DeepARTester,
    path_to_data="C:\\Users\\itay3\\VirtualCodeProjects\\AppLearner-1\\data\\",
    tests_to_perform=test_to_perform
)
tb.run_training_and_tests()
# Out:
# [DeepAR TEST BENCH] Powering on test bench
# [DeepAR TEST BENCH] testing metric='container_cpu', app='kube-rbac-proxy'.
# [DeepAR TEST BENCH] Fetching data for metric='container_cpu', app='kube-rbac-proxy'.
# [DeepAR TEST BENCH] Making an instance of the class we want to test.
# [DeepAR TEST BENCH] Starting training loop.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name                   | Type                   | Params
# ------------------------------------------------------------------
# 0 | loss                   | NormalDistributionLoss | 0
# 1 | logging_metrics        | ModuleList             | 0
# 2 | embeddings             | MultiEmbedding         | 200 K
# 3 | rnn                    | LSTM                   | 23.4 K
# 4 | distribution_projector | Linear                 | 62
# ------------------------------------------------------------------
# 223 K     Trainable params
# 0         Non-trainable params
# 223 K     Total params
# 0.896     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# [DeepAR TEST BENCH] Training took 751.5563697814941 seconds.
# [DeepAR TEST BENCH] Starting testing loop
# [DeepAR TEST BENCH] ***********************************************************************
# [DeepAR TEST BENCH] REPORT for                              metric='container_cpu', app='kube-rbac-proxy':
# [DeepAR TEST BENCH] Training time in seconds is             751.5563697814941
# [DeepAR TEST BENCH] MSE over the test set is        0.09440143406391144
# [DeepAR TEST BENCH] Precision over the test set is  0.8291573524475098
# [DeepAR TEST BENCH] Recall over the test set is     0.8402605056762695
# [DeepAR TEST BENCH] F1 over the test set is         0.8346720337867737
# [DeepAR TEST BENCH] MASE over the test set is       0.83196622133255
# [DeepAR TEST BENCH] MAPE over the test set is       1.7633758783340454
# [DeepAR TEST BENCH] ***********************************************************************
# [DeepAR TEST BENCH] Done with metric='container_cpu', app='kube-rbac-proxy'
# [DeepAR TEST BENCH] testing metric='container_cpu', app='dns'.
# [DeepAR TEST BENCH] Fetching data for metric='container_cpu', app='dns'.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name                   | Type                   | Params
# ------------------------------------------------------------------
# 0 | loss                   | NormalDistributionLoss | 0
# 1 | logging_metrics        | ModuleList             | 0
# 2 | embeddings             | MultiEmbedding         | 19.8 K
# 3 | rnn                    | LSTM                   | 17.0 K
# 4 | distribution_projector | Linear                 | 62
# ------------------------------------------------------------------
# 36.9 K    Trainable params
# 0         Non-trainable params
# 36.9 K    Total params
# 0.148     Total estimated model params size (MB)
# [DeepAR TEST BENCH] Making an instance of the class we want to test.
# [DeepAR TEST BENCH] Starting training loop.
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [DeepAR TEST BENCH] Training took 302.2962529659271 seconds.
# [DeepAR TEST BENCH] Starting testing loop
# [DeepAR TEST BENCH] ***********************************************************************
# [DeepAR TEST BENCH] REPORT for                              metric='container_cpu', app='dns':
# [DeepAR TEST BENCH] Training time in seconds is             302.2962529659271
# [DeepAR TEST BENCH] MSE over the test set is        0.08687135577201843
# [DeepAR TEST BENCH] Precision over the test set is  0.8464146256446838
# [DeepAR TEST BENCH] Recall over the test set is     0.8587891459465027
# [DeepAR TEST BENCH] F1 over the test set is         0.8525570034980774
# [DeepAR TEST BENCH] MASE over the test set is       0.8462140560150146
# [DeepAR TEST BENCH] MAPE over the test set is       1.1860427856445312
# [DeepAR TEST BENCH] ***********************************************************************
# [DeepAR TEST BENCH] Done with metric='container_cpu', app='dns'
# [DeepAR TEST BENCH] Powering off test bench
