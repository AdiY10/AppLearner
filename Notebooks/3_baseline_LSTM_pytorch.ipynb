# %%
import our_src.scinet as scient
import src.framework__test_bench as bench
import src.framework__data_set as ds

# %%
test_to_perform = (
    # Container CPU
    {"metric": "container_mem", "app": "kube-rbac-proxy", "prediction length": 20, "sub sample rate": 30, "data length limit": 84},
    # {"metric": "container_cpu", "app": "dns",             "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_cpu", "app": "collector",       "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # Container Memory
    # {"metric": "container_mem", "app": "nmstate-handler", "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_mem", "app": "coredns",         "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_mem", "app": "keepalived",      "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # Node Memory
    # {"metric": "node_mem",      "app": "moc/smaug",       "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "node_mem",      "app": "emea/balrog",     "prediction length": 16, "sub sample rate": 30, "data length limit": 30}
)

# %%
tb = bench.TestBench(
        class_to_test=scient.PytorchSCITester,
        path_to_data="../data/OperatreFirst_PrometheusData_AppLearner/OperatreFirst_PrometheusData_AppLearner/",
        tests_to_perform=test_to_perform
    )
tb.run_training_and_tests()
# Out:
# [TEST BENCH] Powering on test bench
# [TEST BENCH] testing metric='container_mem', app='kube-rbac-proxy'.
# [TEST BENCH] Fetching data for metric='container_mem', app='kube-rbac-proxy'.
# ['container_mem_2022-06-08_14_00_00_to_2022-06-13_21_00_00.json', 'container_cpu_2022-06-08_17_00_00_to_2022-06-13_21_00_00.json', 'container_mem_2022-04-30_16_00_00_to_2022-05-12_21_00_00.json', 'container_mem_2022-05-12_21_00_00_to_2022-05-28_14_00_00.json', 'container_cpu_2022-04-19_17_00_00_to_2022-04-30_16_00_00.json', 'container_cpu_2022-05-28_17_00_00_to_2022-06-08_17_00_00.json', 'container_cpu_2022-04-30_16_00_00_to_2022-05-12_22_00_00.json', 'container_mem_2022-05-28_14_00_00_to_2022-06-08_14_00_00.json', 'container_mem_2022-04-19_17_00_00_to_2022-04-30_16_00_00.json', 'container_cpu_2022-05-12_22_00_00_to_2022-05-28_17_00_00.json', 'node_mem_2022-05-28_10_00_00_to_2022-06-13_21_00_00.json']
# [TEST BENCH] Subsampling data from 1 sample per 1 minute to 1 sample per 30 minutes.
# [TEST BENCH] Throwing out data that is less than 42.0 hours long.
# [TEST BENCH] Scaling data.
# [TEST BENCH] Splitting data into train and test.
# [TEST BENCH] Amount of train/test data is 284.
# [TEST BENCH] Making an instance of the class we want to test.
# [PytorchLSTMTester] model = SCINet(
#   (blocks1): EncoderTree(
#     (SCINet_Tree): SCINet_Tree(
#       (workingblock): LevelSCINet(
#         (interact): InteractorLevel(
#           (level): Interactor(
#             (split): Splitting()
#             (phi): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (psi): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (P): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (U): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#           )
#         )
#       )
#       (SCINet_Tree_odd): SCINet_Tree(
#         (workingblock): LevelSCINet(
#           (interact): InteractorLevel(
#             (level): Interactor(
#               (split): Splitting()
#               (phi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (psi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (P): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (U): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#             )
#           )
#         )
#       )
#       (SCINet_Tree_even): SCINet_Tree(
#         (workingblock): LevelSCINet(
#           (interact): InteractorLevel(
#             (level): Interactor(
#               (split): Splitting()
#               (phi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (psi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (P): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (U): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (projection1): Conv1d(40, 20, kernel_size=(1,), stride=(1,), bias=False)
#   (div_projection): ModuleList()
# )
# [PytorchLSTMTester] optimizer = Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: False
#     initial_lr: 0.0005
#     lr: 0.0005
#     maximize: False
#     weight_decay: 0
# )
# [PytorchLSTMTester] optimizer = <torch.optim.lr_scheduler.ExponentialLR object at 0x7f62c4ec5160>
# [PytorchLSTMTester] criterion = MSELoss()
# [TEST BENCH] Starting training loop.
# number of training samples = 12622
# Epoch 1 done. Epoch time was 20.025747537612915. Average loss for the batches in epoch is 0.14582649009255103
# Epoch 2 done. Epoch time was 20.063036680221558. Average loss for the batches in epoch is 0.007050824867372837
# Epoch 3 done. Epoch time was 19.98811650276184. Average loss for the batches in epoch is 0.005751101194609759
# Epoch 4 done. Epoch time was 19.937939405441284. Average loss for the batches in epoch is 0.00527569338313858
# Epoch 5 done. Epoch time was 19.9759783744812. Average loss for the batches in epoch is 0.005038582331123703
# Epoch 6 done. Epoch time was 19.855729579925537. Average loss for the batches in epoch is 0.0048893621645254804
# Epoch 7 done. Epoch time was 19.392780542373657. Average loss for the batches in epoch is 0.004757279241339693
# Epoch 8 done. Epoch time was 17.926084995269775. Average loss for the batches in epoch is 0.004659869946551191
# Epoch 9 done. Epoch time was 17.97595453262329. Average loss for the batches in epoch is 0.004563872191960676
# Epoch 10 done. Epoch time was 17.971227407455444. Average loss for the batches in epoch is 0.0044893111435319235
# Epoch 11 done. Epoch time was 17.90832829475403. Average loss for the batches in epoch is 0.00442239039436077
# Epoch 12 done. Epoch time was 17.895888566970825. Average loss for the batches in epoch is 0.004355623532982566
# Epoch 13 done. Epoch time was 17.89379382133484. Average loss for the batches in epoch is 0.004299338389176262
# Epoch 14 done. Epoch time was 17.975611925125122. Average loss for the batches in epoch is 0.0042442627407351064
# Epoch 15 done. Epoch time was 17.974998474121094. Average loss for the batches in epoch is 0.004195013149535354
# [TEST BENCH] Training took 282.8782196044922 seconds.
# [TEST BENCH] Starting testing loop
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] REPORT for                              metric='container_mem', app='kube-rbac-proxy':
# [TEST BENCH] Training time in seconds is             282.8782196044922
# [TEST BENCH] Average mse over the test set is        0.005880962764370384
# [TEST BENCH] Average precision over the test set is  0.5357138460131416
# [TEST BENCH] Average recall over the test set is     0.48995089880467924
# [TEST BENCH] Average F1 over the test set is         0.5025581370698555
# [TEST BENCH] Average MASE over the test set is       4284062456949.9746
# [TEST BENCH] Average MAPE over the test set is       0.541197473818113
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] Done with metric='container_mem', app='kube-rbac-proxy'
# [TEST BENCH] | metric | app | training time | mse | precision | recall | F1 | MASE | MAPE |
# [TEST BENCH] | container_mem | kube-rbac-proxy | 283 seconds   | 0.00588 | 0.53571 | 0.48995 | 0.50256  | 4284062456949.9746 | 0.5412 |
# [TEST BENCH] Powering off test bench
