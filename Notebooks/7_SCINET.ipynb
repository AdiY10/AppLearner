# %%
import sys
sys.path.insert(2, "/home/alon.kitin/AppLearner")
import src.framework__test_bench_scinet as bench
import src.framework__scinet as scient
import src.framework__data_set_scinet as ds

# %%
test_to_perform = (
    # Container CPU
    {"metric": "container_mem", "app": "kube-rbac-proxy", "prediction length": 20, "sub sample rate": 30, "data length limit": 84},
    # {"metric": "container_cpu", "app": "dns",             "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_cpu", "app": "collector",       "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # Container Memory
    # {"metric": "container_mem", "app": "nmstate-handler", "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_mem", "app": "coredns",         "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_mem", "app": "keepalived",      "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # Node Memory
    # {"metric": "node_mem",      "app": "moc/smaug",       "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "node_mem",      "app": "emea/balrog",     "prediction length": 16, "sub sample rate": 30, "data length limit": 30}
)

# %%
tb = bench.TestBench(
        class_to_test=scient.PytorchSCITester,
        # path_to_data="../data/OperatreFirst_PrometheusData_AppLearner/",
        path_to_data="/home/alon.kitin/server_danger_ai/data/OperatreFirst_PrometheusData_AppLearner/OperatreFirst_PrometheusData_AppLearner/",
        tests_to_perform=test_to_perform
    )
tb.run_training_and_tests()
# Out:
# [TEST BENCH] Powering on test bench
# [TEST BENCH] testing metric='container_mem', app='kube-rbac-proxy'.
# [TEST BENCH] Fetching data for metric='container_mem', app='kube-rbac-proxy'.
# ['container_cpu_2022-04-19_17_00_00_to_2022-04-30_16_00_00.json', 'container_cpu_2022-04-30_16_00_00_to_2022-05-12_22_00_00.json', 'container_cpu_2022-05-12_22_00_00_to_2022-05-28_17_00_00.json', 'container_cpu_2022-05-28_17_00_00_to_2022-06-08_17_00_00.json', 'container_cpu_2022-06-08_17_00_00_to_2022-06-13_21_00_00.json', 'container_mem_2022-04-19_17_00_00_to_2022-04-30_16_00_00.json', 'container_mem_2022-04-30_16_00_00_to_2022-05-12_21_00_00.json', 'container_mem_2022-05-12_21_00_00_to_2022-05-28_14_00_00.json', 'container_mem_2022-05-28_14_00_00_to_2022-06-08_14_00_00.json', 'container_mem_2022-06-08_14_00_00_to_2022-06-13_21_00_00.json', 'node_mem_2022-05-28_10_00_00_to_2022-06-13_21_00_00.json']
# [TEST BENCH] Subsampling data from 1 sample per 1 minute to 1 sample per 30 minutes.
# [TEST BENCH] Throwing out data that is less than 42.0 hours long.
# [TEST BENCH] Scaling data.
# [TEST BENCH] Splitting data into train and test.
# [TEST BENCH] Amount of train/test data is 284.
# [TEST BENCH] Making an instance of the class we want to test.
# [PytorchLSTMTester] model = SCINet(
#   (blocks1): EncoderTree(
#     (SCINet_Tree): SCINet_Tree(
#       (workingblock): LevelSCINet(
#         (interact): InteractorLevel(
#           (level): Interactor(
#             (split): Splitting()
#             (phi): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (psi): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (P): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (U): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#           )
#         )
#       )
#       (SCINet_Tree_odd): SCINet_Tree(
#         (workingblock): LevelSCINet(
#           (interact): InteractorLevel(
#             (level): Interactor(
#               (split): Splitting()
#               (phi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (psi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (P): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (U): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#             )
#           )
#         )
#       )
#       (SCINet_Tree_even): SCINet_Tree(
#         (workingblock): LevelSCINet(
#           (interact): InteractorLevel(
#             (level): Interactor(
#               (split): Splitting()
#               (phi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (psi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (P): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (U): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (projection1): Conv1d(40, 20, kernel_size=(1,), stride=(1,), bias=False)
#   (div_projection): ModuleList()
# )
# [PytorchLSTMTester] optimizer = Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: False
#     initial_lr: 0.0005
#     lr: 0.0005
#     maximize: False
#     weight_decay: 0
# )
# [PytorchLSTMTester] optimizer = <torch.optim.lr_scheduler.ExponentialLR object at 0x7f1c47dae940>
# [PytorchLSTMTester] criterion = MSELoss()
# [TEST BENCH] Starting training loop.
# number of training samples = 12622
# Epoch 1 done. Epoch time was 13.832411766052246. Average loss for the batches in epoch is 0.1231875045024613
# Epoch 2 done. Epoch time was 12.37308669090271. Average loss for the batches in epoch is 0.007587309329051383
# Epoch 3 done. Epoch time was 12.295551776885986. Average loss for the batches in epoch is 0.005887281118385211
# Epoch 4 done. Epoch time was 12.5803964138031. Average loss for the batches in epoch is 0.005343939651605449
# Epoch 5 done. Epoch time was 16.32911968231201. Average loss for the batches in epoch is 0.0050457974253340235
# Epoch 6 done. Epoch time was 16.456857919692993. Average loss for the batches in epoch is 0.004883772748392782
# Epoch 7 done. Epoch time was 16.49241590499878. Average loss for the batches in epoch is 0.004747184118126295
# Epoch 8 done. Epoch time was 12.370612621307373. Average loss for the batches in epoch is 0.004650117158653992
# Epoch 9 done. Epoch time was 16.445379972457886. Average loss for the batches in epoch is 0.004542361747155178
# Epoch 10 done. Epoch time was 16.446507453918457. Average loss for the batches in epoch is 0.004453181218992494
# Epoch 11 done. Epoch time was 16.439891576766968. Average loss for the batches in epoch is 0.00439107883338451
# Epoch 12 done. Epoch time was 16.45305609703064. Average loss for the batches in epoch is 0.004302480479089331
# Epoch 13 done. Epoch time was 12.277574300765991. Average loss for the batches in epoch is 0.004240542397645738
# Epoch 14 done. Epoch time was 12.25589394569397. Average loss for the batches in epoch is 0.004182033985853195
# Epoch 15 done. Epoch time was 12.339131593704224. Average loss for the batches in epoch is 0.004137385335951289
# Epoch 16 done. Epoch time was 12.31547498703003. Average loss for the batches in epoch is 0.004096792405176484
# Epoch 17 done. Epoch time was 12.371604204177856. Average loss for the batches in epoch is 0.004049572005243147
# Epoch 18 done. Epoch time was 12.25789737701416. Average loss for the batches in epoch is 0.004009886034705405
# Epoch 19 done. Epoch time was 16.365984201431274. Average loss for the batches in epoch is 0.003965416147750861
# Epoch 20 done. Epoch time was 15.97791600227356. Average loss for the batches in epoch is 0.003940021948700276
# [TEST BENCH] Training took 284.747430562973 seconds.
# [TEST BENCH] Starting testing loop
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] REPORT for                              metric='container_mem', app='kube-rbac-proxy':
# [TEST BENCH] Training time in seconds is             284.747430562973
# [TEST BENCH] Average mse over the test set is        0.008207053849522259
# [TEST BENCH] Average precision over the test set is  0.5407138147455051
# [TEST BENCH] Average recall over the test set is     0.5095127578541218
# [TEST BENCH] Average F1 over the test set is         0.5148950926790309
# [TEST BENCH] Average MASE over the test set is       4849263574202.188
# [TEST BENCH] Average MAPE over the test set is       0.5519995864176529
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] Done with metric='container_mem', app='kube-rbac-proxy'
# [TEST BENCH] | metric | app | training time | mse | precision | recall | F1 | MASE | MAPE |
# [TEST BENCH] | container_mem | kube-rbac-proxy | 285 seconds   | 0.00821 | 0.54071 | 0.50951 | 0.5149  | 4849263574202.188 | 0.552 |
# [TEST BENCH] Powering off test bench

# %%
print(1)
# Out:
# 1
