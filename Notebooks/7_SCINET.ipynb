# %%
import sys
sys.path.insert(2, "/home/alon.kitin/AppLearner")
import src.framework__test_bench_scinet as bench
import src.framework__scinet as scient
import src.framework__data_set_scinet as ds

# %%
test_to_perform = (
    # Container CPU
    {"metric": "container_mem", "app": "kube-rbac-proxy", "prediction length": 20, "sub sample rate": 30, "data length limit": 84},
    # {"metric": "container_cpu", "app": "dns",             "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_cpu", "app": "collector",       "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # Container Memory
    # {"metric": "container_mem", "app": "nmstate-handler", "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_mem", "app": "coredns",         "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_mem", "app": "keepalived",      "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # Node Memory
    # {"metric": "node_mem",      "app": "moc/smaug",       "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "node_mem",      "app": "emea/balrog",     "prediction length": 16, "sub sample rate": 30, "data length limit": 30}
)

# %%
tb = bench.TestBench(
        class_to_test=scient.PytorchSCITester,
        path_to_data="../data/OperatreFirst_PrometheusData_AppLearner/",
        tests_to_perform=test_to_perform
    )
tb.run_training_and_tests()
# Out:
# [TEST BENCH] Powering on test bench
# [TEST BENCH] testing metric='container_mem', app='kube-rbac-proxy'.
# [TEST BENCH] Fetching data for metric='container_mem', app='kube-rbac-proxy'.
# ['container_mem_2022-06-08_14_00_00_to_2022-06-13_21_00_00.json', 'container_cpu_2022-06-08_17_00_00_to_2022-06-13_21_00_00.json', 'container_mem_2022-04-30_16_00_00_to_2022-05-12_21_00_00.json', 'container_mem_2022-05-12_21_00_00_to_2022-05-28_14_00_00.json', 'container_cpu_2022-04-19_17_00_00_to_2022-04-30_16_00_00.json', 'container_cpu_2022-05-28_17_00_00_to_2022-06-08_17_00_00.json', 'container_cpu_2022-04-30_16_00_00_to_2022-05-12_22_00_00.json', 'container_mem_2022-05-28_14_00_00_to_2022-06-08_14_00_00.json', 'container_mem_2022-04-19_17_00_00_to_2022-04-30_16_00_00.json', 'container_cpu_2022-05-12_22_00_00_to_2022-05-28_17_00_00.json', 'node_mem_2022-05-28_10_00_00_to_2022-06-13_21_00_00.json']
# [TEST BENCH] Subsampling data from 1 sample per 1 minute to 1 sample per 30 minutes.
# [TEST BENCH] Throwing out data that is less than 42.0 hours long.
# [TEST BENCH] Scaling data.
# [TEST BENCH] Splitting data into train and test.
# [TEST BENCH] Amount of train/test data is 284.
# [TEST BENCH] Making an instance of the class we want to test.
# [PytorchLSTMTester] model = SCINet(
#   (blocks1): EncoderTree(
#     (SCINet_Tree): SCINet_Tree(
#       (workingblock): LevelSCINet(
#         (interact): InteractorLevel(
#           (level): Interactor(
#             (split): Splitting()
#             (phi): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (psi): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (P): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (U): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#           )
#         )
#       )
#       (SCINet_Tree_odd): SCINet_Tree(
#         (workingblock): LevelSCINet(
#           (interact): InteractorLevel(
#             (level): Interactor(
#               (split): Splitting()
#               (phi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (psi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (P): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (U): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#             )
#           )
#         )
#       )
#       (SCINet_Tree_even): SCINet_Tree(
#         (workingblock): LevelSCINet(
#           (interact): InteractorLevel(
#             (level): Interactor(
#               (split): Splitting()
#               (phi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (psi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (P): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (U): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (projection1): Conv1d(40, 20, kernel_size=(1,), stride=(1,), bias=False)
#   (div_projection): ModuleList()
# )
# [PytorchLSTMTester] optimizer = Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.0005
#     lr: 0.0005
#     maximize: False
#     weight_decay: 0
# )
# [PytorchLSTMTester] optimizer = <torch.optim.lr_scheduler.ExponentialLR object at 0x7fecc53a1ae0>
# [PytorchLSTMTester] criterion = MSELoss()
# [TEST BENCH] Starting training loop.
# number of training samples = 12622
# Epoch 1 done. Epoch time was 17.402817726135254. Average loss for the batches in epoch is 0.31776842943074396
# Epoch 2 done. Epoch time was 17.49853801727295. Average loss for the batches in epoch is 0.008864386290123191
# Epoch 3 done. Epoch time was 17.429710388183594. Average loss for the batches in epoch is 0.006606093451050641
# Epoch 4 done. Epoch time was 17.346694231033325. Average loss for the batches in epoch is 0.005798691541805298
# Epoch 5 done. Epoch time was 17.393399000167847. Average loss for the batches in epoch is 0.0054037871658566255
# Epoch 6 done. Epoch time was 17.37559151649475. Average loss for the batches in epoch is 0.005128937989732699
# Epoch 7 done. Epoch time was 17.666199684143066. Average loss for the batches in epoch is 0.004928373830110023
# Epoch 8 done. Epoch time was 17.61189889907837. Average loss for the batches in epoch is 0.004760632836967235
# Epoch 9 done. Epoch time was 17.389681100845337. Average loss for the batches in epoch is 0.004626827115263743
# Epoch 10 done. Epoch time was 17.331156015396118. Average loss for the batches in epoch is 0.004513443358348612
# Epoch 11 done. Epoch time was 17.32196831703186. Average loss for the batches in epoch is 0.0044138108663072315
# Epoch 12 done. Epoch time was 17.353639841079712. Average loss for the batches in epoch is 0.004332159784964368
# Epoch 13 done. Epoch time was 17.302218914031982. Average loss for the batches in epoch is 0.004263983662770707
# Epoch 14 done. Epoch time was 17.25922679901123. Average loss for the batches in epoch is 0.00420339782044433
# Epoch 15 done. Epoch time was 17.750855684280396. Average loss for the batches in epoch is 0.0041490649990148
# Epoch 16 done. Epoch time was 17.292598724365234. Average loss for the batches in epoch is 0.0040981154193323625
# Epoch 17 done. Epoch time was 17.314005136489868. Average loss for the batches in epoch is 0.00405183127090995
# Epoch 18 done. Epoch time was 17.256571054458618. Average loss for the batches in epoch is 0.004011698376646713
# Epoch 19 done. Epoch time was 17.35961389541626. Average loss for the batches in epoch is 0.0039801538229295155
# Epoch 20 done. Epoch time was 17.357633352279663. Average loss for the batches in epoch is 0.003944386750506826
# [TEST BENCH] Training took 348.09973096847534 seconds.
# [TEST BENCH] Starting testing loop
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] REPORT for                              metric='container_mem', app='kube-rbac-proxy':
# [TEST BENCH] Training time in seconds is             348.09973096847534
# [TEST BENCH] Average mse over the test set is        0.008410798049804146
# [TEST BENCH] Average precision over the test set is  0.5344806308714759
# [TEST BENCH] Average recall over the test set is     0.5235771625829073
# [TEST BENCH] Average F1 over the test set is         0.5184511907873258
# [TEST BENCH] Average MASE over the test set is       6089591870894.844
# [TEST BENCH] Average MAPE over the test set is       0.5280952648059468
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] Done with metric='container_mem', app='kube-rbac-proxy'
# [TEST BENCH] | metric | app | training time | mse | precision | recall | F1 | MASE | MAPE |
# [TEST BENCH] | container_mem | kube-rbac-proxy | 348 seconds   | 0.00841 | 0.53448 | 0.52358 | 0.51845  | 6089591870894.844 | 0.5281 |
# [TEST BENCH] Powering off test bench

# %%
# %debug
# Out:
# ERROR:root:No traceback has been produced, nothing to debug.
