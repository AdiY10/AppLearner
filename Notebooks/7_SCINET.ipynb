# %%
import sys
sys.path.insert(2, "/home/alon.kitin/AppLearner")
import src.framework__test_bench_scinet as bench
import src.framework__scinet as scient
import src.framework__scinet  as ds

# %%
test_to_perform = (
    # Container CPU
    {"metric": "container_mem", "app": "kube-rbac-proxy", "prediction length": 20, "sub sample rate": 30, "data length limit": 84},
    # {"metric": "container_cpu", "app": "dns",             "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_cpu", "app": "collector",       "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # Container Memory
    # {"metric": "container_mem", "app": "nmstate-handler", "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_mem", "app": "coredns",         "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "container_mem", "app": "keepalived",      "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # Node Memory
    # {"metric": "node_mem",      "app": "moc/smaug",       "prediction length": 16, "sub sample rate": 30, "data length limit": 30},
    # {"metric": "node_mem",      "app": "emea/balrog",     "prediction length": 16, "sub sample rate": 30, "data length limit": 30}
)

# %%
tb = bench.TestBench(
        class_to_test=scient.PytorchSCITester,
        # path_to_data="../data/OperatreFirst_PrometheusData_AppLearner/",
        path_to_data="/home/alon.kitin/server_danger_ai/data/OperatreFirst_PrometheusData_AppLearner/OperatreFirst_PrometheusData_AppLearner/",
        tests_to_perform=test_to_perform
    )
tb.run_training_and_tests()
# Out:
# [TEST BENCH] Powering on test bench
# [TEST BENCH] testing metric='container_mem', app='kube-rbac-proxy'.
# [TEST BENCH] Fetching data for metric='container_mem', app='kube-rbac-proxy'.
# ['container_cpu_2022-04-19_17_00_00_to_2022-04-30_16_00_00.json', 'container_cpu_2022-04-30_16_00_00_to_2022-05-12_22_00_00.json', 'container_cpu_2022-05-12_22_00_00_to_2022-05-28_17_00_00.json', 'container_cpu_2022-05-28_17_00_00_to_2022-06-08_17_00_00.json', 'container_cpu_2022-06-08_17_00_00_to_2022-06-13_21_00_00.json', 'container_mem_2022-04-19_17_00_00_to_2022-04-30_16_00_00.json', 'container_mem_2022-04-30_16_00_00_to_2022-05-12_21_00_00.json', 'container_mem_2022-05-12_21_00_00_to_2022-05-28_14_00_00.json', 'container_mem_2022-05-28_14_00_00_to_2022-06-08_14_00_00.json', 'container_mem_2022-06-08_14_00_00_to_2022-06-13_21_00_00.json', 'node_mem_2022-05-28_10_00_00_to_2022-06-13_21_00_00.json']
# [TEST BENCH] Subsampling data from 1 sample per 1 minute to 1 sample per 30 minutes.
# [TEST BENCH] Throwing out data that is less than 42.0 hours long.
# [TEST BENCH] Scaling data.
# [TEST BENCH] Splitting data into train and test.
# [TEST BENCH] Amount of train/test data is 198.
# [TEST BENCH] Making an instance of the class we want to test.
# [PytorchLSTMTester] model = SCINet(
#   (blocks1): EncoderTree(
#     (SCINet_Tree): SCINet_Tree(
#       (workingblock): LevelSCINet(
#         (interact): InteractorLevel(
#           (level): Interactor(
#             (split): Splitting()
#             (phi): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (psi): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (P): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#             (U): Sequential(
#               (0): ReplicationPad1d((3, 3))
#               (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#               (2): LeakyReLU(negative_slope=0.01, inplace=True)
#               (3): Dropout(p=0.5, inplace=False)
#               (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#               (5): Tanh()
#             )
#           )
#         )
#       )
#       (SCINet_Tree_odd): SCINet_Tree(
#         (workingblock): LevelSCINet(
#           (interact): InteractorLevel(
#             (level): Interactor(
#               (split): Splitting()
#               (phi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (psi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (P): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (U): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#             )
#           )
#         )
#       )
#       (SCINet_Tree_even): SCINet_Tree(
#         (workingblock): LevelSCINet(
#           (interact): InteractorLevel(
#             (level): Interactor(
#               (split): Splitting()
#               (phi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (psi): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (P): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#               (U): Sequential(
#                 (0): ReplicationPad1d((3, 3))
#                 (1): Conv1d(1, 256, kernel_size=(5,), stride=(1,))
#                 (2): LeakyReLU(negative_slope=0.01, inplace=True)
#                 (3): Dropout(p=0.5, inplace=False)
#                 (4): Conv1d(256, 1, kernel_size=(3,), stride=(1,))
#                 (5): Tanh()
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (projection1): Conv1d(40, 20, kernel_size=(1,), stride=(1,), bias=False)
#   (div_projection): ModuleList()
# )
# [PytorchLSTMTester] optimizer = Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: False
#     initial_lr: 0.0005
#     lr: 0.0005
#     maximize: False
#     weight_decay: 0
# )
# [PytorchLSTMTester] optimizer = <torch.optim.lr_scheduler.ExponentialLR object at 0x7f31bfd14ca0>
# [PytorchLSTMTester] criterion = MSELoss()
# [TEST BENCH] Starting training loop.
# number of training samples = 12825
# Epoch 1 done. Epoch time was 12.093766450881958. Average loss for the batches in epoch is 0.26349154349527976
# Epoch 2 done. Epoch time was 9.805380582809448. Average loss for the batches in epoch is 0.013454086847482552
# Epoch 3 done. Epoch time was 9.855273723602295. Average loss for the batches in epoch is 0.009657997163035848
# Epoch 4 done. Epoch time was 14.10738730430603. Average loss for the batches in epoch is 0.008245719449845448
# Epoch 5 done. Epoch time was 14.13839054107666. Average loss for the batches in epoch is 0.00757515830675284
# Epoch 6 done. Epoch time was 14.67354154586792. Average loss for the batches in epoch is 0.007215538038930245
# Epoch 7 done. Epoch time was 14.128756999969482. Average loss for the batches in epoch is 0.006937970345180268
# Epoch 8 done. Epoch time was 12.367011547088623. Average loss for the batches in epoch is 0.006746434593837978
# Epoch 9 done. Epoch time was 14.09276294708252. Average loss for the batches in epoch is 0.006584541896529997
# Epoch 10 done. Epoch time was 14.095168590545654. Average loss for the batches in epoch is 0.006451679852342888
# Epoch 11 done. Epoch time was 12.304868936538696. Average loss for the batches in epoch is 0.006271629916513316
# Epoch 12 done. Epoch time was 14.492360591888428. Average loss for the batches in epoch is 0.006164377193231405
# Epoch 13 done. Epoch time was 14.357853889465332. Average loss for the batches in epoch is 0.0060472473478353495
# Epoch 14 done. Epoch time was 12.35445499420166. Average loss for the batches in epoch is 0.005941652663242527
# Epoch 15 done. Epoch time was 12.325863599777222. Average loss for the batches in epoch is 0.005840583535159783
# Epoch 16 done. Epoch time was 12.51356554031372. Average loss for the batches in epoch is 0.005722755871357819
# Epoch 17 done. Epoch time was 14.12397050857544. Average loss for the batches in epoch is 0.005651103386927182
# Epoch 18 done. Epoch time was 14.100488424301147. Average loss for the batches in epoch is 0.005550841832512576
# Epoch 19 done. Epoch time was 14.13568377494812. Average loss for the batches in epoch is 0.005456265982384433
# Epoch 20 done. Epoch time was 13.382469177246094. Average loss for the batches in epoch is 0.005418283176815086
# [TEST BENCH] Training took 263.5528619289398 seconds.
# [TEST BENCH] Starting testing loop
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] REPORT for                              metric='container_mem', app='kube-rbac-proxy':
# [TEST BENCH] Training time in seconds is             263.5528619289398
# [TEST BENCH] Average mse over the test set is        0.0030454930637031307
# [TEST BENCH] Average precision over the test set is  0.5364198463035668
# [TEST BENCH] Average recall over the test set is     0.540096665540362
# [TEST BENCH] Average F1 over the test set is         0.5317547995814166
# [TEST BENCH] Average MASE over the test set is       1159424638182.069
# [TEST BENCH] Average MAPE over the test set is       0.611005667779741
# [TEST BENCH] ***********************************************************************
# [TEST BENCH] Done with metric='container_mem', app='kube-rbac-proxy'
# [TEST BENCH] | metric | app | training time | mse | precision | recall | F1 | MASE | MAPE |
# [TEST BENCH] | container_mem | kube-rbac-proxy | 264 seconds   | 0.00305 | 0.53642 | 0.5401 | 0.53175  | 1159424638182.069 | 0.61101 |
# [TEST BENCH] Powering off test bench

# %%
print(1)
# Out:
# 1
